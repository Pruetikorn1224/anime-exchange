# %% [markdown]
# # Anime Recommendation
#
# This notebook analysed Japanese anime data and create a recommendation model using 2 approaches, which are Content-based Approach and Collaborative Filtering Approach (Matrix Factorization).
#
# The dataset was downloaded from Kaggle, and created originally by HERNAN VALDIVIESO. This dataset contains information about 17,562 anime and the preference from 325,772 different users. It can be access in this file through path `./dataset/`.
#
# - `anime-dataset-2023.csv` : information of anime
# - `animelist.csv`: the list of anime registered by users
# - `users-details-2023.csv`: information of users
#
# [Dataset Link](https://www.kaggle.com/datasets/dbdmobile/myanimelist-dataset/)

# %% [markdown]
# ## Dependencies
#
# Import all required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

import os
import re

# %load_ext autoreload
# %autoreload 2

print("Numpy version - ", np.__version__)
print("Pandas version - ", pd.__version__)
print("Matplotlib version - ", mpl.__version__)
# Out:
# Numpy version -  1.26.4
# Pandas version -  2.2.3
# Matplotlib version -  3.9.2

# %%
# %reload_ext autoreload

# %%
# Load files
file_path = './dataset/'
files = {}
for file in os.listdir(file_path):
    if os.path.isfile(os.path.join(file_path, file)) and file != '.DS_Store':
        f = file.split('.')[0]
        files[f] = file
        print(f)
# Out:
# users-score-2023
# anime-dataset-2023
# users-details-2023

# %% [markdown]
# ## Data Cleaning
#
# This module contains the part reading csv files, and cleaning the NULL data.

# %% [markdown]
# ### Anime

# %%
# anime.csv
anime_df = pd.read_csv(os.path.join(file_path, files['anime-dataset-2023']))
anime_df.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name Score  \
# 0                         カウボーイビバップ  8.75
# 1                    カウボーイビバップ 天国の扉  8.38
# 2                             トライガン  8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)  7.25
# 4                            冒険王ビィト  6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24905 entries, 0 to 24904
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  object
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  object
#  9   Aired         24905 non-null  object
#  10  Premiered     24905 non-null  object
#  11  Status        24905 non-null  object
#  12  Producers     24905 non-null  object
#  13  Licensors     24905 non-null  object
#  14  Studios       24905 non-null  object
#  15  Source        24905 non-null  object
#  16  Duration      24905 non-null  object
#  17  Rating        24905 non-null  object
# ...

# %%
anime_df.isnull().sum()
# Out:
# anime_id        0
# Name            0
# English name    0
# Other name      0
# Score           0
# Genres          0
# Synopsis        0
# Type            0
# Episodes        0
# Aired           0
# Premiered       0
# Status          0
# Producers       0
# Licensors       0
# Studios         0
# Source          0
# Duration        0
# Rating          0
# Rank            0
# Popularity      0
# Favorites       0
# Scored By       0
# Members         0
# Image URL       0
# dtype: int64

# %%
anime_df['Score'] = anime_df['Score'].replace('UNKNOWN', '0.00')
anime_df['Score'] = anime_df['Score'].astype(float)

anime_df['Episodes'] = pd.to_numeric(anime_df['Episodes'].replace('UNKNOWN', -1), errors='coerce')
anime_df['Episodes'] = anime_df['Episodes'].fillna(-1).astype(int)

anime_df['Rank'] = pd.to_numeric(anime_df['Rank'], errors='coerce')
anime_df['Rank'] = anime_df['Rank'].fillna(-1).round().astype(int)

anime_df['Scored By'] = pd.to_numeric(anime_df['Scored By'], errors='coerce')
anime_df['Scored By'] = anime_df['Scored By'].fillna(-1).round().astype(int)

# %%
def split_date(aired_date):
    date = re.findall(r'\b[A-Za-z]{3} \d{1,2}, \d{4}\b', aired_date)
    if len(date) == 2:
        return date[0], date[1]
    elif len(date) == 1:
        return date[0], None
    else:
        return None, None

anime_df[['Start date', 'End date']] = anime_df['Aired'].apply(split_date).apply(pd.Series)
anime_df = anime_df.drop('Aired', axis=1)

# %%
anime_df = anime_df.sort_values(by='anime_id')
anime_df.head()
# Out:
#    anime_id                             Name             English name  \
# 0         1                     Cowboy Bebop             Cowboy Bebop
# 1         5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2         6                           Trigun                   Trigun
# 3         7               Witch Hunter Robin       Witch Hunter Robin
# 4         8                   Bouken Ou Beet   Beet the Vandel Buster
#
#                          Other name  Score  \
# 0                         カウボーイビバップ   8.75
# 1                    カウボーイビバップ 天国の扉   8.38
# 2                             トライガン   8.22
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)   7.25
# 4                            冒険王ビィト   6.94
#
#                                  Genres  \
# 0         Action, Award Winning, Sci-Fi
# 1                        Action, Sci-Fi
# 2             Action, Adventure, Sci-Fi
# 3  Action, Drama, Mystery, Supernatural
# 4      Adventure, Fantasy, Supernatural
#
# ...

# %%
anime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24905 entries, 0 to 24904
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anime_id      24905 non-null  int64
#  1   Name          24905 non-null  object
#  2   English name  24905 non-null  object
#  3   Other name    24905 non-null  object
#  4   Score         24905 non-null  float64
#  5   Genres        24905 non-null  object
#  6   Synopsis      24905 non-null  object
#  7   Type          24905 non-null  object
#  8   Episodes      24905 non-null  int64
#  9   Premiered     24905 non-null  object
#  10  Status        24905 non-null  object
#  11  Producers     24905 non-null  object
#  12  Licensors     24905 non-null  object
#  13  Studios       24905 non-null  object
#  14  Source        24905 non-null  object
#  15  Duration      24905 non-null  object
#  16  Rating        24905 non-null  object
#  17  Rank          24905 non-null  int64
# ...

# %% [markdown]
# ### Users

# %%
# animelist.csv
users_df = pd.read_csv(os.path.join(file_path, files['users-details-2023']))
users_df.head()
# Out:
#    Mal ID Username  Gender                   Birthday              Location  \
# 0       1    Xinil    Male  1985-03-04T00:00:00+00:00            California
# 1       3  Aokaado    Male                        NaN          Oslo, Norway
# 2       4  Crystal  Female                        NaN  Melbourne, Australia
# 3       9   Arcane     NaN                        NaN                   NaN
# 4      18      Mad     NaN                        NaN                   NaN
#
#                       Joined  Days Watched  Mean Score  Watching  Completed  \
# 0  2004-11-05T00:00:00+00:00         142.3        7.37       1.0      233.0
# 1  2004-11-11T00:00:00+00:00          68.6        7.34      23.0      137.0
# 2  2004-11-13T00:00:00+00:00         212.8        6.68      16.0      636.0
# 3  2004-12-05T00:00:00+00:00          30.0        7.71       5.0       54.0
# 4  2005-01-03T00:00:00+00:00          52.0        6.27       1.0      114.0
#
# ...

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731290 entries, 0 to 731289
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Mal ID            731290 non-null  int64
#  1   Username          731289 non-null  object
#  2   Gender            224383 non-null  object
#  3   Birthday          168068 non-null  object
#  4   Location          152805 non-null  object
#  5   Joined            731290 non-null  object
#  6   Days Watched      731282 non-null  float64
#  7   Mean Score        731282 non-null  float64
#  8   Watching          731282 non-null  float64
#  9   Completed         731282 non-null  float64
#  10  On Hold           731282 non-null  float64
#  11  Dropped           731282 non-null  float64
#  12  Plan to Watch     731282 non-null  float64
#  13  Total Entries     731282 non-null  float64
#  14  Rewatched         731282 non-null  float64
# ...

# %%
users_df.isnull().sum()
# Out:
# Mal ID                   0
# Username                 1
# Gender              506907
# Birthday            563222
# Location            578485
# Joined                   0
# Days Watched             8
# Mean Score               8
# Watching                 8
# Completed                8
# On Hold                  8
# Dropped                  8
# Plan to Watch            8
# Total Entries            8
# Rewatched                8
# Episodes Watched         8
# dtype: int64

# %%
changing_columns = ['Days Watched', 'Watching', 'Completed', 'On Hold', 
                    'Dropped', 'Plan to Watch', 'Total Entries', 'Rewatched', 'Episodes Watched']

users_df[changing_columns] = users_df[changing_columns].fillna(-1)
users_df[changing_columns] = users_df[changing_columns].replace([np.inf, -np.inf], -1)

users_df[changing_columns] = users_df[changing_columns].astype(int)

# %%
users_df.rename(columns={'Mal ID': 'user_id', 'B': 'Y', 'C': 'Z'}, inplace=True)

# %%
def calculate_age(birthdate):
    from datetime import datetime
    
    if pd.isna(birthdate):  # Handle NaN values
        return None
        
    birth_date = datetime.fromisoformat(birthdate)
    today = datetime.now()
    return today.year - birth_date.year - ((today.month, today.day) < (birth_date.month, birth_date.day))

users_df['Age'] = users_df['Birthday'].apply(calculate_age)

# %%
users_df.head()
# Out:
#    user_id Username  Gender                   Birthday              Location  \
# 0        1    Xinil    Male  1985-03-04T00:00:00+00:00            California
# 1        3  Aokaado    Male                        NaN          Oslo, Norway
# 2        4  Crystal  Female                        NaN  Melbourne, Australia
# 3        9   Arcane     NaN                        NaN                   NaN
# 4       18      Mad     NaN                        NaN                   NaN
#
#                       Joined  Days Watched  Mean Score  Watching  Completed  \
# 0  2004-11-05T00:00:00+00:00           142        7.37         1        233
# 1  2004-11-11T00:00:00+00:00            68        7.34        23        137
# 2  2004-11-13T00:00:00+00:00           212        6.68        16        636
# 3  2004-12-05T00:00:00+00:00            30        7.71         5         54
# 4  2005-01-03T00:00:00+00:00            52        6.27         1        114
#
# ...

# %%
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731290 entries, 0 to 731289
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           731290 non-null  int64
#  1   Username          731289 non-null  object
#  2   Gender            224383 non-null  object
#  3   Birthday          168068 non-null  object
#  4   Location          152805 non-null  object
#  5   Joined            731290 non-null  object
#  6   Days Watched      731290 non-null  int64
#  7   Mean Score        731282 non-null  float64
#  8   Watching          731290 non-null  int64
#  9   Completed         731290 non-null  int64
#  10  On Hold           731290 non-null  int64
#  11  Dropped           731290 non-null  int64
#  12  Plan to Watch     731290 non-null  int64
#  13  Total Entries     731290 non-null  int64
#  14  Rewatched         731290 non-null  int64
#  15  Episodes Watched  731290 non-null  int64
# ...

# %% [markdown]
# ### Rating Score

# %%
# rating_complete.csv
rating_df = pd.read_csv(os.path.join(file_path, files['users-score-2023']))
rating_df.head()
# Out:
#    user_id Username  anime_id             Anime Title  rating
# 0        1    Xinil        21               One Piece       9
# 1        1    Xinil        48             .hack//Sign       7
# 2        1    Xinil       320                  A Kite       5
# 3        1    Xinil        49        Aa! Megami-sama!       8
# 4        1    Xinil       304  Aa! Megami-sama! Movie       8

# %%
rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24325191 entries, 0 to 24325190
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user_id      int64
#  1   Username     object
#  2   anime_id     int64
#  3   Anime Title  object
#  4   rating       int64
# dtypes: int64(3), object(2)
# memory usage: 927.9+ MB

# %%
rating_df.isnull().sum()
# Out:
# user_id          0
# Username       232
# anime_id         0
# Anime Title      0
# rating           0
# dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
df_copy = anime_df.copy()

# %%
df_u_copy = users_df.copy()

# %%
df_r_copy = rating_df.copy()

# %%
df_copy = df_copy.sort_values(by='Score', ascending=False)
df_copy[['anime_id', 'Name', 'Score', 'Scored By']].head(10)
# Out:
#        anime_id                                               Name  Score  \
# 3961       5114                   Fullmetal Alchemist: Brotherhood   9.10
# 16617     41467                          Bleach: Sennen Kessen-hen   9.07
# 5667       9253                                        Steins;Gate   9.07
# 9880      28977                                           Gintama°   9.06
# 14865     38524                 Shingeki no Kyojin Season 3 Part 2   9.05
# 22348     51535  Shingeki no Kyojin: The Final Season - Kankets...   9.05
# 17572     43608         Kaguya-sama wa Kokurasetai: Ultra Romantic   9.05
# 6456      11061                             Hunter x Hunter (2011)   9.04
# 15525     39486                                 Gintama: The Final   9.04
# 5989       9969                                           Gintama'   9.04
#
#        Scored By
# 3961     2020030
# 16617     213872
# 5667     1336233
# 9880      237957
# 14865    1471825
# 22348     155773
# 17572     451187
# ...

# %%
df_copy = df_copy[df_copy['Popularity'] != 0].sort_values(by='Popularity', ascending=True)
df_copy[['anime_id', 'Name', 'Popularity']].head(10)
# Out:
#        anime_id                              Name  Popularity
# 7428      16498                Shingeki no Kyojin           1
# 1393       1535                        Death Note           2
# 3961       5114  Fullmetal Alchemist: Brotherhood           3
# 10408     30276                     One Punch Man           4
# 6596      11757                  Sword Art Online           5
# 11134     31964             Boku no Hero Academia           6
# 14539     38000                  Kimetsu no Yaiba           7
# 10           20                            Naruto           8
# 8619      22319                       Tokyo Ghoul           9
# 6456      11061            Hunter x Hunter (2011)          10

# %%
df_copy = df_copy.sort_values(by='Members', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.barh(df_copy['Name'], df_copy['Members'], color='skyblue')

for index, value in enumerate(df_copy['Members']):
    plt.text(value, index, str(value), va='center', ha='right', fontsize=10)
    
plt.title('Members')
plt.xlabel('Members')
plt.ylabel('Name')
plt.tight_layout()
plt.show()

# %%
df_copy = df_copy.sort_values(by='Favorites', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.barh((df_copy['Name']), df_copy['Favorites'], color='salmon')

for index, value in enumerate(df_copy['Favorites']):
    plt.text(value, index, str(value), va='center', ha='right', fontsize=10)

plt.title('Favorites Ranking')
plt.xlabel('Favorites')
plt.ylabel('Name')
plt.tight_layout()
plt.show()

# %%
def percentage_member_favorite(members, favorites):
    if members <= 0:
        return None
    return (float(favorites) / float(members)) * 100

df_copy['Favorite Rate'] = df_copy.apply(lambda x: percentage_member_favorite(x.Members, x.Favorites), axis=1)
df_copy = df_copy.sort_values(by='Favorite Rate', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.barh(df_copy['Name'], df_copy['Favorite Rate'], color='gold')

for index, value in enumerate(df_copy['Favorite Rate']):
    plt.text(value, index, f"{value:.2f}%", va='center', ha='right', fontsize=10)
    
plt.title('Favorite Rate')
plt.xlabel('Favorite Rate')
plt.ylabel('Name')
plt.tight_layout()
plt.show()

# %%
all_genres = df_copy['Genres'].str.split(', ').explode()
genre_counts = all_genres.value_counts()

plt.figure(figsize=(6, 10))
genre_counts.plot(kind='barh', color='lightgreen')

for index, value in enumerate(genre_counts):
    if value < 500:
        plt.text(value, index, str(value), va='center', ha='left', fontsize=10)
    else:
        plt.text(value, index, str(value), va='center', ha='right', fontsize=10)

plt.title('Genre Counts', fontsize=16)
plt.xlabel('Anime Count', fontsize=10)
plt.ylabel('Genre', fontsize=10)
plt.show()

# %%
rating_counts = df_r_copy['rating'].value_counts()
rating_counts = rating_counts.sort_index()

plt.figure(figsize=(8, 8))
rating_counts.plot(kind='bar')

plt.title('Rating Counts', fontsize=16)
plt.xlabel('Rating Score', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.show()

# %%
df_copy = df_copy[df_copy['Score'] != 0]

plt.figure(figsize=(8, 6))
plt.hist(df_copy['Score'], bins=10, edgecolor='black', color='crimson')

plt.title('Histogram of Score', fontsize=16)
plt.xlabel('Score', fontsize=14)
plt.ylabel('Frequency', fontsize=14)

plt.tight_layout()
plt.show()

# %%
genre_list = df_copy['Genres'].str.split(', ').explode().unique()
list_scores = {}

for genre in genre_list:
    df_partial = anime_df.copy()
    df_partial = df_partial[df_partial['Score'] != 0.00]

    df_g = df_partial[df_partial['Genres'].str.contains(genre)]
    list_scores[genre] = list(df_g['Score'])

labels = list(list_scores.keys())
values = list(list_scores.values())

plt.figure(figsize=(6, 12))
plt.boxplot(values, tick_labels=labels, vert=False)
plt.title("Box Plot of Genres' Score")
plt.xlabel("Genres")
plt.ylabel("Score")
# plt.xticks(rotation=90)
plt.grid(alpha=0.4)
plt.show()

# %%
type_counts = df_copy['Type'].value_counts()

plt.figure(figsize=(6, 6))
type_counts.plot(kind='pie', autopct='%1.1f%%')

plt.title('Type Counts', fontsize=16)
plt.xlabel('Type', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.show()

# %%
source_counts = df_copy['Source'].value_counts()

threshold = 0.01  # 5%
total = source_counts.sum()

source_counts_adjusted = source_counts[source_counts / total >= threshold]
source_counts_adjusted['Others'] = source_counts[source_counts / total < threshold].sum()

plt.figure(figsize=(8, 8))
source_counts_adjusted.plot(kind='pie', autopct='%1.1f%%')

plt.title('Source Counts', fontsize=16)
plt.ylabel('')
plt.show()

# %%
studio_counts = df_copy['Studios'].value_counts().head(11)

plt.figure(figsize=(10, 6))
studio_counts.plot(kind='bar', color='orangered')

plt.title('Studio Counts', fontsize=16)
plt.xlabel('Count', fontsize=10)
plt.ylabel('Studios', fontsize=10)
plt.show()

# %%
sorted_column = ['G - All Ages', 'PG - Children', 'PG-13 - Teens 13 or older', 'R - 17+ (violence & profanity)',
                'R+ - Mild Nudity', 'Rx - Hentai', 'UNKNOWN']
rating_counts = df_copy['Rating'].value_counts()
rating_counts = rating_counts.reindex(sorted_column).fillna(0)

plt.figure(figsize=(10, 6))
rating_counts.plot(kind='bar', color='violet')

plt.title('Rating Counts', fontsize=16)
plt.xlabel('Rating', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.show()

# %%
df_copy = df_copy[df_copy['Episodes'] != -1]
type_counts = df_copy['Episodes'].value_counts().head(10)

plt.figure(figsize=(6, 6))
type_counts.plot(kind='bar', color='lightcoral')

plt.title('Episodes Counts', fontsize=16)
plt.xlabel('Episodes', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.show()

# %%
count_columns = ['Watching', 'Completed', 'On Hold', 'Dropped', 'Plan to Watch']
counts = []

for col in count_columns:
    val = df_u_copy[col].sum()
    counts.append(val)

plt.figure(figsize=(6, 6))
plt.pie(counts, labels = count_columns, autopct='%1.1f%%')
plt.legend(title = "Watching Status")
plt.show()

# %%
# df_u_copy = df_u_copy[df_u_copy['Gender'] != np.nan]
gender_counts = df_u_copy['Gender'].fillna('Not Reveal').value_counts()

plt.figure(figsize=(6, 6))
gender_counts.plot(kind='pie', autopct='%1.1f%%')

plt.title('Gender Counts', fontsize=16)
plt.xlabel('Type', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.show()

# %%
df_u_copy = df_u_copy[pd.notna(df_u_copy['Age'])]
df_u_copy = df_u_copy[df_u_copy['Age'] < 100]
max_age = df_u_copy['Age'].max()

plt.figure(figsize=(8, 6))
plt.hist(df_u_copy['Age'], bins=range(0, 100, 10), edgecolor='black')

plt.title('Histogram of Age', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.tight_layout()
plt.show()

# %%
df_1 = df_copy[['anime_id', 'Genres']]
df_2 = df_u_copy[['user_id', 'Gender']]
df_3 = df_r_copy[['anime_id', 'user_id']]

merge_df = pd.merge(df_3, df_1, on='anime_id', how='left')
merge_df = pd.merge(merge_df, df_2, on='user_id', how='left').fillna('UNKNOWN')

merge_df['Genres'] = merge_df['Genres'].str.split(', ').explode('Genres')

grouped = merge_df.groupby(['Genres', 'Gender']).size().unstack(fill_value=0)
grouped.plot(kind='bar', figsize=(12, 8), colormap='spring')

plt.title('Genres Distribution by Gender', fontsize=16)
plt.xlabel('Genres', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Gender', loc='upper right')
plt.tight_layout()
plt.show()

# %%
grouped = df_u_copy.groupby('Gender')['Mean Score'].mean().reset_index()
print(grouped)
# Out:
#        Gender  Mean Score
# 0      Female    6.709868
# 1        Male    6.880727
# 2  Non-Binary    7.175525

# %%
df_1 = df_copy[['anime_id', 'Genres']]
df_2 = df_u_copy[['user_id', 'Gender']]
df_3 = df_r_copy[['anime_id', 'user_id', 'rating']]

merge_df = pd.merge(df_3, df_1, on='anime_id', how='left')
merge_df = pd.merge(merge_df, df_2, on='user_id', how='left').fillna('UNKNOWN')

merge_df['Genres'] = merge_df['Genres'].str.split(', ').explode('Genres')

average_ratings = merge_df.groupby(['Genres', 'Gender'])['rating'].mean().reset_index()
pivot_table = average_ratings.pivot(index='Genres', columns='Gender', values='rating')

pivot_table.plot(kind='bar', figsize=(12, 8), colormap='Wistia')

plt.title('Average Rating of Genres Distributed by Genders', fontsize=16)
plt.xlabel('Genres', fontsize=12)
plt.ylabel('Average Rating', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.ylim(7, 7.8)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %%
genre_list = df_copy['Genres'].str.split(', ').explode().unique()
anime_most_score = []

for genre in genre_list:
    df_partial = anime_df.copy()
    df_g = df_partial[df_partial['Genres'].str.contains(genre, na=False)]

    if not df_g.empty:
        max_row = df_g.loc[df_g['Score'].idxmax()]
        anime_most_score.append({'Genre': genre, 'Name': max_row['Name'], 'Score': max_row['Score']})

result_df = pd.DataFrame(anime_most_score)
print(result_df)
# Out:
#             Genre                                               Name  Score
# 0          Action                   Fullmetal Alchemist: Brotherhood   9.10
# 1   Award Winning                                     Koe no Katachi   8.94
# 2          Sci-Fi                                        Steins;Gate   9.07
# 3       Adventure                   Fullmetal Alchemist: Brotherhood   9.10
# 4           Drama                   Fullmetal Alchemist: Brotherhood   9.10
# 5         Mystery                         Owarimonogatari 2nd Season   8.88
# 6    Supernatural                           Fruits Basket: The Final   9.00
# 7         Fantasy                   Fullmetal Alchemist: Brotherhood   9.10
# 8          Sports  Haikyuu!! Karasuno Koukou vs. Shiratorizawa Ga...   8.78
# 9          Comedy                                           Gintama°   9.06
# 10        Romance         Kaguya-sama wa Kokurasetai: Ultra Romantic   9.05
# ...

# %%
genre_list = df_copy['Genres'].str.split(', ').explode().unique()
anime_most_members = []

for genre in genre_list:
    df_partial = anime_df.copy()
    df_g = df_partial[df_partial['Genres'].str.contains(genre, na=False)]

    if not df_g.empty:
        max_row = df_g.loc[df_g['Members'].idxmax()]
        anime_most_members.append({'Genre': genre, 'Name': max_row['Name'], 'Members': max_row['Members']})

result_df = pd.DataFrame(anime_most_members)
print(result_df)
# Out:
#             Genre                              Name  Members
# 0          Action                Shingeki no Kyojin  3744541
# 1   Award Winning                Shingeki no Kyojin  3744541
# 2          Sci-Fi                       Steins;Gate  2440369
# 3       Adventure  Fullmetal Alchemist: Brotherhood  3176556
# 4           Drama                Shingeki no Kyojin  3744541
# 5         Mystery           Boku dake ga Inai Machi  1994083
# 6    Supernatural                        Death Note  3713315
# 7         Fantasy  Fullmetal Alchemist: Brotherhood  3176556
# 8          Sports                         Haikyuu!!  1870150
# 9          Comedy                     One Punch Man  3058666
# 10        Romance                  Sword Art Online  2951821
# 11  Slice of Life                            Hyouka  1315575
# 12       Suspense                Shingeki no Kyojin  3744541
# 13          Ecchi                   No Game No Life  2305805
# ...

# %%
genre_list = df_copy['Genres'].str.split(', ').explode().unique()
anime_most_favorite = []

for genre in genre_list:
    df_partial = anime_df.copy()
    df_g = df_partial[df_partial['Genres'].str.contains(genre, na=False)]

    if not df_g.empty:
        max_row = df_g.loc[df_g['Favorites'].idxmax()]
        anime_most_favorite.append({'Genre': genre, 'Name': max_row['Name'], 'Favorites': max_row['Favorites']})

result_df = pd.DataFrame(anime_most_favorite)
print(result_df)
# Out:
#             Genre                              Name  Favorites
# 0          Action  Fullmetal Alchemist: Brotherhood     217606
# 1   Award Winning                Shingeki no Kyojin     163844
# 2          Sci-Fi                       Steins;Gate     182964
# 3       Adventure  Fullmetal Alchemist: Brotherhood     217606
# 4           Drama  Fullmetal Alchemist: Brotherhood     217606
# 5         Mystery                    Bakemonogatari      48111
# 6    Supernatural                        Death Note     167586
# 7         Fantasy  Fullmetal Alchemist: Brotherhood     217606
# 8          Sports                         Haikyuu!!      70904
# 9          Comedy                     One Punch Man      62408
# 10        Romance           Shigatsu wa Kimi no Uso      83560
# 11  Slice of Life                            Hyouka      26320
# 12       Suspense                       Steins;Gate     182964
# 13          Ecchi                   No Game No Life      47444
# ...

# %%
from datetime import datetime

current_year = 2023
range_year = 10

def split_premier_date(premier_date):
    if premier_date == np.nan or premier_date == 'UNKNOWN':
        return np.nan, np.nan
    
    date = premier_date.split()
    if date[1].isdigit():
        if date[0] not in ['summer', 'winter', 'spring', 'fall']:
            return np.nan, np.nan
        return date[0], int(date[1])
    else:
        return np.nan, np.nan

df_copy[['Premier_Month', 'Premier_Year']] = df_copy['Premiered'].apply(split_premier_date).apply(pd.Series)
df_copy = df_copy.dropna(subset=['Premier_Year'])
df_copy = df_copy[(df_copy['Premier_Year'] >= current_year - range_year) & (df_copy['Premier_Year'] <= current_year)]
df_copy['Premier_Year'] = df_copy['Premier_Year'].astype(int)

# %%
df_sum = df_copy.groupby(['Premier_Year', 'Premier_Month'])['Members'].sum().reset_index()
pivot_table = df_sum.pivot(index='Premier_Year', columns='Premier_Month', values='Members')
pivot_table.plot(kind='bar', figsize=(12, 8), colormap='cool')
plt.title('Members by Premier Year and Month', fontsize=16)
plt.xlabel('Years', fontsize=12)
plt.ylabel('Members', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Season')
plt.tight_layout()
plt.show()

# %%
df_sum = df_copy.groupby(['Premier_Year', 'Premier_Month'])['Favorites'].sum().reset_index()
pivot_table = df_sum.pivot(index='Premier_Year', columns='Premier_Month', values='Favorites')
pivot_table.plot(kind='bar', figsize=(12, 8), colormap='cool')
plt.title('Favorites by Premier Year and Month', fontsize=16)
plt.xlabel('Years', fontsize=12)
plt.ylabel('Favorites', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Season')
plt.tight_layout()
plt.show()

# %%
df_sum = df_copy.groupby(['Premier_Year', 'Premier_Month'])['Score'].mean().reset_index()
pivot_table = df_sum.pivot(index='Premier_Year', columns='Premier_Month', values='Score')
pivot_table.plot(kind='bar', figsize=(12, 8), colormap='cool')
plt.title('Average Score by Premier Year and Month', fontsize=16)
plt.xlabel('Years', fontsize=12)
plt.ylabel('Average Score', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Season')
plt.tight_layout()
plt.show()

# %%
def percentage_member_favorite(members, favorites):
    if members <= 0:
        return None
    return (float(favorites) / float(members)) * 100

df_copy['Favorite Rate'] = df_copy.apply(lambda x: percentage_member_favorite(x.Members, x.Favorites), axis=1)

df_sum = df_copy.groupby(['Premier_Year', 'Premier_Month'])['Favorite Rate'].mean().reset_index()
pivot_table = df_sum.pivot(index='Premier_Year', columns='Premier_Month', values='Favorite Rate')
pivot_table.plot(kind='bar', figsize=(12, 8), colormap='cool')
plt.title('Favorite Rate by Premier Year and Month', fontsize=16)
plt.xlabel('Years', fontsize=12)
plt.ylabel('Favorite Rate', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Season')
plt.tight_layout()
plt.show()

# %%
df_sum = df_copy.groupby(['Premier_Year', 'Type']).size().unstack(fill_value=0)
df_sum.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='gist_rainbow')

plt.title('Stacked Bar Graph of Types by Premier Year', fontsize=16)
plt.xlabel('Premier Year', fontsize=12)
plt.ylabel('Count of Types', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Recommendation System: Content-based Filtering
#
# uses the attributes or features of an item  (this is the content part) to recommend other items similar to the user’s preferences. This approach is based on similarity of item and user features,  given information about a user and items they have interacted with (e.g. a user’s age, the category of a restaurant’s cuisine, the average review for a movie),  model the likelihood of a new interaction.
#
# [Reference](https://www.nvidia.com/en-us/glossary/recommendation-system/)

# %% [markdown]
# The similarity score will be calculated into 3 parts, and combine all them together with different weight.
#
# - Genres: Calculating the similarity using cosine similarity from genre vectors.
# - Synopsis: Calculating text similarity using TF-IDF
# - Attributes: Calculating from vectors composed of Studio, Rating, Type. The matching attribute will contribute the point to this part.

# %% [markdown]
# ### Genres

# %%
unique_genres = set(', '.join(anime_df['Genres']).split(', '))
unique_genres.discard('UNKNOWN')
genre_columns = sorted(unique_genres)

print(f"There are total {len(genre_columns)} genres\n", genre_columns)
# Out:
# There are total 43 genres
#  ['Action', 'Adventure', 'Cars', 'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game', 'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic', 'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody', 'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi', 'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai', 'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural', 'Thriller', 'Vampire', 'Yaoi', 'Yuri']

# %%
genres_matrix = np.zeros(shape=(len(anime_df), len(genre_columns)), dtype=int)

genre_to_index = {genre: idx for idx, genre in enumerate(genre_columns)}

for i, row in anime_df.iterrows():
    genres = row['Genres'].split(', ')
    for genre in genres:
        if genre == 'UNKNOWN':
            continue
        genres_matrix[i, genre_to_index[genre]] = 1

genres_df = pd.DataFrame(genres_matrix, columns=genre_columns, index=anime_df['anime_id'])
genres_df.head(10)
# Out:
#         Action  Adventure  Cars  Comedy  Dementia  Demons  Drama  Ecchi  \
# MAL_ID
# 1            1          1     0       1         0       0      1      0
# 5            1          0     0       0         0       0      1      0
# 6            1          1     0       1         0       0      1      0
# 7            1          0     0       0         0       0      1      0
# 8            0          1     0       0         0       0      0      0
# 15           1          0     0       1         0       0      0      0
# 16           0          0     0       1         0       0      1      0
# 17           0          0     0       1         0       0      0      0
# 18           1          0     1       0         0       0      1      0
# 19           0          0     0       0         0       0      1      0
#
#         Fantasy  Game  ...  Shounen Ai  Slice of Life  Space  Sports  \
# MAL_ID                 ...
# ...

# %%
dot_product = np.dot(genres_matrix, genres_matrix.T)

norms = np.linalg.norm(genres_matrix, axis=1)
norms_matrix = np.outer(norms, norms)

norms_matrix[norms_matrix == 0] = 1
genre_similarity = dot_product / norms_matrix

genre_similarity_df = pd.DataFrame(genre_similarity, columns=anime_df['MAL_ID'], index=anime_df['MAL_ID'])
genre_similarity_df.head(10)
# Out:
# MAL_ID     1         5         6         7         8         15        16     \
# MAL_ID
# 1       1.000000  0.730297  0.833333  0.333333  0.204124  0.408248  0.365148
# 5       0.730297  1.000000  0.547723  0.547723  0.000000  0.223607  0.200000
# 6       0.833333  0.547723  1.000000  0.333333  0.408248  0.612372  0.365148
# 7       0.333333  0.547723  0.333333  1.000000  0.204124  0.204124  0.182574
# 8       0.204124  0.000000  0.408248  0.204124  1.000000  0.250000  0.000000
# 15      0.408248  0.223607  0.612372  0.204124  0.250000  1.000000  0.223607
# 16      0.365148  0.200000  0.365148  0.182574  0.000000  0.223607  1.000000
# 17      0.204124  0.000000  0.408248  0.000000  0.250000  0.750000  0.447214
# 18      0.365148  0.400000  0.365148  0.365148  0.000000  0.447214  0.200000
# 19      0.154303  0.338062  0.154303  0.462910  0.000000  0.000000  0.169031
#
# MAL_ID     17        18        19     ...     48456     48466     48470  \
# ...

# %%
def search_top_similarity(anime, n=5, similarities=genre_similarity):
    
    if type(anime) != int and type(anime) != str:
        print("The value should contain anime's name or ID")
        return None

    try:
        top_similarities = []
        aId = None
        if type(anime) == int:
            if anime in anime_df['MAL_ID']:
                aId = anime_df.index[anime_df['MAL_ID'] == anime]
            else:
                print("No existing ID in this dataset")
                return None
        elif type(anime) == str:
            if anime in anime_df['Name']:
                aId = anime_df.index[anime_df['Name'] == anime]
            else:
                print("No existing name in this dataset")
                return None
        
        top_similarities = np.argsort(similarities[aId])[0][-(n+1):-1]
        return top_similarities
    
    except:
        print("Error")

# %%
anime_id = 3229

top_s = search_top_similarity(anime_id, n=10)

if top_s is not None:
    df_top = anime_df["Name"].loc[top_s]
    print("I have watched {}, and it recommends".format(anime_df[anime_df['MAL_ID']==anime_id]['Name'].values))
    for top in df_top: print("\t-",top)
# Out:
# I have watched ['Kimi ga Aruji de Shitsuji ga Ore de'], and it recommends
# 	- Saenai Heroine no Sodatekata: Ai to Seishun no Service-kai
# 	- Akaneiro ni Somaru Saka: Hardcore
# 	- Hanaukyou Maid-tai: La Verite
# 	- Oniichan no Koto nanka Zenzen Suki ja Nai n da kara ne!!
# 	- Love♥Love? Specials
# 	- Hanaukyou Maid-tai
# 	- Hanaukyou Maid-tai OVA
# 	- Love Hina Final Selection
# 	- Love♥Love?
# 	- R-15: R15 Shounen Hyouryuuki

# %%
anime_id = 456

top_s = search_top_similarity(anime_id, n=10)

if top_s is not None:
    df_top = anime_df["Name"].loc[top_s]
    print("I have watched {}, and it recommends".format(anime_df[anime_df['MAL_ID']==anime_id]['Name'].values))
    for top in df_top: print("\t-",top)
# Out:
# I have watched ['Gokujou Seitokai'], and it recommends
# 	- Azumanga Web Daioh
# 	- Gokujou Seitokai
# 	- Hidamari Sketch Recap
# 	- Musashino!
# 	- Hidamari Sketch x 365 Recap
# 	- Minami-ke
# 	- Yuyushiki: Komarasetari, Komarasaretari
# 	- Wakaba*Girl
# 	- Minami-ke Tadaima
# 	- Urashimasakatasen no Nichijou

# %% [markdown]
# ### Attributes

# %% [markdown]
# ### Synopsis

# %% [markdown]
# ## Recommendation System: Collaborative filtering
#
# recommend items (this is the filtering part) based on preference information from many users (this is the collaborative part). This approach uses similarity of user preference behavior,  given previous interactions between users and items, recommender algorithms learn to predict future interaction.
#
# [Reference](https://www.nvidia.com/en-us/glossary/recommendation-system/)
